# %%
#imports
import cadquery as cq
from cadquery.vis import show

# %%
bicep_2d=cq.importers.importDXF("assets/svg/dxf_derivatives/flame_inner.dxf")
bicep_3d = cq.Workplane("XY").add(bicep_2d).extrude(3.0)

# %%
show(bicep_3d)
